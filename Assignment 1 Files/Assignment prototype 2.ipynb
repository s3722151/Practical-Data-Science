# %%
#Make the file (before exporting)
#1.We create the mainfile
import pandas as pd
import matplotlib.pyplot as plt
Mainfile = pd.read_csv('Manufacturer.csv', sep=',', decimal='.')
Mainfile

 #This I now can read the file. I can now read the other files.This is from the Week 2 slides - Missing Values
file1 = pd.read_csv('Model.csv',sep=',', decimal='.')
file2 = pd.read_csv('Price.csv',sep=',', decimal='.')
file3 = pd.read_csv('Transmission.csv',sep=',', decimal='.')
file4 = pd.read_csv('Power.csv',sep=',', decimal='.')
file5 = pd.read_csv('Engine CC.csv',sep=',', decimal='.')
file6 = pd.read_csv('Fuel.csv',sep=',', decimal='.')
file7 = pd.read_csv('Female.csv',sep=',', decimal='.')
file8 = pd.read_csv('Male.csv',sep=',', decimal='.')
file9 = pd.read_csv('Unknown.csv',sep=',', decimal='.')
file10 = pd.read_csv('Total.csv',sep=',', decimal='.')

 #Add the files together based on the shared Index.
Mainfile ['Model'] = (file1['Model'])
Mainfile ['Price'] = (file2['Price'])
Mainfile ['Transmission'] = (file3['Transmission'])
Mainfile ['Power'] = (file4['Power'])
Mainfile ['Engine CC'] = (file5['Engine CC'])
Mainfile ['Fuel'] = (file6['Fuel'])
Mainfile ['Female'] = (file7['Female'])
Mainfile ['Male'] = (file8['Male'])
Mainfile ['Unknown'] = (file9['Unknown'])
Mainfile ['Total'] = (file10['Total'])

# %%
#2.We the clean the file
 #Rename the unamed column then delete it - It is redundant information.
list(Mainfile)
Mainfile.rename(columns = {'Unnamed: 0': 'Index'}, inplace =True)
Mainfile = Mainfile.drop(columns=['Index'])
Mainfile
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 0            Ford     Focus   30.619322      5.966102  -94.033898
# 1            Ford    Fiesta   18.532143   5000.714286   68.571429
# 2      Volkswagen      Golf   31.242154      6.164835  -89.461538
# 3         Renault      Clio   22.100000      5.615385   75.576923
# 4             BMW      320i   47.848370      6.444444  126.111111
# ...           ...       ...         ...           ...         ...
# 6097   Land-Rover  Defender  108.747195      7.853659  207.609756
# 6098       Toyota      RAV4   43.548516      1.354839  137.774193
# 6099   Alfa-Romeo    Spider   55.200000      6.000000  163.500000
# 6100        Honda   Shuttle   30.081000      4.000000  110.000000
# 6101   Mitsubishi     Space   23.165158      3.947368   82.157895
#
#         Engine CC    Fuel  Female    Male Unknown    Total
# 0     1497.169492  petrol  422731  814172  56,487  1293390
# ...

# %%
 #Make sure to round all values with decimals to 4 places.
Mainfile['Price'] = Mainfile['Price'].round(2)
Mainfile['Transmission'] = Mainfile['Transmission'].round(2)
Mainfile['Power'] = Mainfile['Power'].round(2)
Mainfile['Engine CC'] = Mainfile['Engine CC'].round(2)

# %%
 #Getting rid of comma's in our decimal values
Mainfile['Female'] = Mainfile['Female'].str.replace(',', '')
Mainfile['Male'] = Mainfile['Male'].str.replace(',', '')
Mainfile['Unknown'] = Mainfile['Unknown'].str.replace(',', '')
Mainfile['Total'] = Mainfile['Total'].str.replace(',', '')
Mainfile
# Out:
#      Manufacturer     Model   Price  Transmission   Power  Engine CC    Fuel  \
# 0            Ford     Focus   30.62          5.97  -94.03    1497.17  petrol
# 1            Ford    Fiesta   18.53       5000.71   68.57    1166.14  petrol
# 2      Volkswagen      Golf   31.24          6.16  -89.46    1537.41  petrol
# 3         Renault      Clio   22.10          5.62   75.58    1219.65  petrol
# 4             BMW      320i   47.85          6.44  126.11    1995.78  petrol
# ...           ...       ...     ...           ...     ...        ...     ...
# 6097   Land-Rover  Defender  108.75          7.85  207.61    2304.98  diesel
# 6098       Toyota      RAV4   43.55          1.35  137.77    2261.19  petrol
# 6099   Alfa-Romeo    Spider   55.20          6.00  163.50    2696.50  petrol
# 6100        Honda   Shuttle   30.08          4.00  110.00    2254.00  petrol
# 6101   Mitsubishi     Space   23.17          3.95   82.16    1817.32  petrol
#
#       Female    Male Unknown    Total
# ...

# %%
 #We strip white spaces with values that use strings. 
  #This doesn't work on Price, Power and Engine CC. 
  #We notice that we cannot remove reundant spaces of values that have integer values(Price, Transmission, #Power, Engine CC, Female, Male,Unknown, Total)
Mainfile['Manufacturer'] = Mainfile['Manufacturer'].str.strip()
Mainfile['Model'] = Mainfile['Model'].str.strip()
#Mainfile['Price'] = Mainfile['Price'].str.strip()
#Mainfile['Power'] = Mainfile['Power'].str.strip()
#Mainfile['Engine CC'] = Mainfile['Engine CC'].str.strip()
Mainfile['Fuel'] = Mainfile['Fuel'].str.strip()
Mainfile['Male'] = Mainfile['Male'].str.strip()
Mainfile['Female'] = Mainfile['Female'].str.strip()
Mainfile['Unknown'] = Mainfile['Unknown'].str.strip()
Mainfile['Total'] = Mainfile['Total'].str.strip()
Mainfile.shape
# Out:
# (6102, 11)

# %%
 #Remove values outside of our range or that are blank.
  #NOTE: I could not execute the conditions for Engine CC
Mainfile.dropna()
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Price <= 0.0)].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Price > 650.0)].index)
# Alternate way: Mainfile = Mainfile.drop(Mainfile[(Mainfile.Price < 0.0) & (Mainfile.Price > 650.0)].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Transmission <= 0.0)].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Transmission > 10.0)].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Power < 0.0)].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Power >500.0)].index)
#Mainfile = Mainfile.drop(Mainfile[(Mainfile.Engine CC< 0.0) & (Mainfile.Engine CC >6500.0)].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Fuel == "")].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Male == "")].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Female == "")].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Unknown == "")].index)
Mainfile = Mainfile.drop(Mainfile[(Mainfile.Total == "")].index)
Mainfile.head(10)
# Out:
#    Manufacturer   Model  Price  Transmission   Power  Engine CC    Fuel  \
# 3       Renault    Clio  22.10          5.62   75.58    1219.65  petrol
# 4           BMW    320i  47.85          6.44  126.11    1995.78  petrol
# 5    Volkswagen    Polo  18.19          5.07   60.96    1408.06  petrol
# 6       Peugeot     206  20.03          4.83   71.33    1631.50  petrol
# 7          Ford  Mondeo  39.97          1.75  130.25    1998.50  petrol
# 8        Nissan   Micra  20.38          4.87   67.96    1279.70  petrol
# 9         Honda   Civic  29.94          4.50  106.22    1480.58  petrol
# 10         Ford     Ka+  15.46          5.00   60.80    1196.00  petrol
# 11      Renault  Megane  26.45          5.41   87.31    1623.79  petrol
# 12       Toyota   Yaris  20.72          3.52   74.40    1397.80  petrol
#
#     Female    Male Unknown   Total
# 3   312556  241287   28004  581847
# 4   115843  408016   29125  552984
# 5   299110  216333   31701  547144
# ...

# %%
Mainfile.loc[Mainfile['Engine CC'] < 0]
Mainfile.loc[Mainfile['Engine CC'] > 6500]
#Inspiration from https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Price, Transmission, Power, Engine CC, Fuel, Female, Male, Unknown, Total]
# Index: []

# %%
#Impossible values - #We identify any NULL values and try to substitute them.
### <=== This is WRONG 
#Mask_Transmission = Mainfile['Transmission'] > 10
#Mask_Transmission = Mainfile['Transmission'] < 0
# Mask_Transmission.head(10) or Mask_Transmission.tail(10)


Mainfile.loc[Mainfile['Transmission'] > 10]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Price, Transmission, Power, Engine CC, Fuel, Female, Male, Unknown, Total]
# Index: []

# %%
# Attempting to fill in empty spaces 2
Mainfile['Price'].fillna(Mainfile['Price'].mean(axis=0))
Mainfile['Transmission'].fillna(Mainfile['Transmission'].mean(axis=0))
Mainfile['Power'].fillna(Mainfile['Power'].mean(axis=0))
Mainfile['Engine CC'].fillna(Mainfile['Engine CC'].mean(axis=0))
#Mainfile['Male'].fillna(Mainfile['Male'].mean(axis=0))
# Out:
# 3       1219.65
# 4       1995.78
# 5       1408.06
# 6       1631.50
# 7       1998.50
#          ...
# 6097    2304.98
# 6098    2261.19
# 6099    2696.50
# 6100    2254.00
# 6101    1817.32
# Name: Engine CC, Length: 5961, dtype: float64

# %%
#Extra test

# %%
#3.Writing the file to a new CSV file.
Mainfile.to_csv('cleaned_car_buyers.csv', index=False)

# %%
#Other miscellaneous functions - APPENDIX
#1) We check the name of the columns - specifically the unnamed Index.
#file2.columns
#Y = file2[['Unnamed: 0', 'Price']]
#Y

#2) How to look at a specific value
#This was a way I could verify in PYTHON an empty field after searching manually. where the observation 23 has an empty field. 
#test = Mainfile['Fuel']
#test[23]

#3) 
#Alternate way of sorting values to find outliers - Run individually. 
# Manufacturing 
#Mainfile.sort_values(['Manufacturing'],ascending=True)
#Mainfile.sort_values(['Manufacturing'],ascending=False)

# Price
#Mainfile.sort_values(['Price'],ascending=True)
#Mainfile.sort_values(['Price'],ascending=False)

# For Transmission 
#Mainfile.sort_values(['Transmission'],ascending=True)
#Mainfile.sort_values(['Transmission'],ascending=False)

# For Power
#Mainfile.sort_values(['Power'],ascending=True)
#Mainfile.sort_values(['Power'],ascending=False)

# For Engine CC
#Mainfile.sort_values(['Engine CC'],ascending=True)
#Mainfile.sort_values(['Engine CC'],ascending=False)

# For Female
#Mainfile.sort_values(['Female'],ascending=True).head(20)
#Mainfile.sort_values(['Female'],ascending=False).head(20)

# For Male
#Mainfile.sort_values(['Male'],ascending=True).head(20)
#Mainfile.sort_values(['Male'],ascending=False).head(20)

#4)Delete values. - Here is an example of deleting an outlier
# Mainfile = Mainfile[Mainfile.Power != -94.033898]

# %%
#Section 2.1
 #Summing is not the correct response
Mainfile.groupby(['Model']).agg(
{'Male': sum
})
#https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
# Out:
#                                                      Male
# Model
# 09-May  2690929522315943353535025346543338631247286302...
# 100     8301043129117682443328044746161845710774132861...
# 1007                     30613140325633473235317829231847
# 104                                       720108615462384
# 105                               71811401786251832614196
# ...                                                   ...
# Z4      1934318193169061532114317122071035176885878441...
# ZR      1947722209244742574526973277262804428381283602...
# ZT      1066011854128421361114308144961447914337130851...
# ZX      3972582984691206417216240253205641342521286105...
# Zafira                  675723749752758761762759757710671
#
# [485 rows x 1 columns]

# %%
# 2.1 continued
TopTenModel = Mainfile.copy()
TopTenModel = TopTenModel.drop(columns=['Price'])
TopTenModel = TopTenModel.drop(columns=['Power'])
TopTenModel = TopTenModel.drop(columns=['Transmission'])
TopTenModel = TopTenModel.drop(columns=['Engine CC'])
TopTenModel = TopTenModel.drop(columns=['Fuel'])

TopTenModel = Mainfile.groupby('Model')[['Model','Male','Female','Unknown','Total']].head(1)
TopTenModel = TopTenModel.sort_values(['Total'],ascending=False).head(10)
TopTenModel

#What is grouping and how to do it: https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
#How to add rows together: https://www.adamsmith.haus/python/answers/how-to-sum-rows-of-a-pandas-dataframe-in-python
# Out:
#       Model   Male Female Unknown  Total
# 56     Leon  65505  30221    3778  99504
# 57       XE  79176  13946    3968  97090
# 58   Fusion  51517  41027    4395  96939
# 59   Accord  74157  15889    5274  95320
# 60     MX-5  47900  39519    5986  93405
# 61        6  71632  17216    4536  93384
# 632     XKR   7853    981     428   9262
# 62       C1  30691  57228    4503  92422
# 228  Citigo   3867   4960     404   9231
# 229   Liana   5205   3467     543   9215

# %%
TopTenModel['Sex'].value_counts()
# Out:
# 'LeonXEFusionAccordMX-56XKRC1CitigoLiana'

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
Male = [65505, 79176, 51517, 74157, 47900]
Female = [30221, 13946, 41027, 15889, 39519]
Unknown = [3778, 3968, 4395, 5274, 5986]
 
# Set position of bar on X axis
br1 = np.arange(len(Male))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, Male, color ='r', width = barWidth,
        edgecolor ='grey', label ='Male')
plt.bar(br2, Female, color ='g', width = barWidth,
        edgecolor ='grey', label ='Female')
plt.bar(br3, Unknown, color ='b', width = barWidth,
        edgecolor ='grey', label ='Unknown')
 
# Adding Xticks
plt.xlabel('Car Model', fontweight ='bold', fontsize = 15)
plt.ylabel('No. of people', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(Male))],
        ['Leon', 'XE', 'Fusion', 'Accord', 'MX-5'])

plt.title('Top 10 Car Models ranked 1 to 5')
plt.legend(title = 'Legend')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
Male = [71632, 7853, 30691, 3867, 5205]
Female = [17216, 981, 57228, 4960, 3467]
Unknown = [4536, 428, 4503, 404, 543]
 
# Set position of bar on X axis
br1 = np.arange(len(Male))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, Male, color ='r', width = barWidth,
        edgecolor ='grey', label ='Male')
plt.bar(br2, Female, color ='g', width = barWidth,
        edgecolor ='grey', label ='Female')
plt.bar(br3, Unknown, color ='b', width = barWidth,
        edgecolor ='grey', label ='Unknown')
 
# Adding Xticks
plt.xlabel('Car Model', fontweight ='bold', fontsize = 15)
plt.ylabel('No. of people', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(Male))],
        ['6', 'Xkr', 'C1', 'Citigo', 'Liana'])

plt.title('Top 10 Car Models ranked 6 to 10')
plt.legend(title = 'Legend')
plt.show()

# %%
#1st Car that is popular
import numpy as np
import matplotlib.pyplot as plt

y = np.array([65505, 30221, 3668])
mylabels = ["Male", "Female", "Unknown"]
myexplode = [0.2, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, autopct='%.2f')
plt.legend(title = 'Preference 1:Leon')
plt.show()

# %%
#2nd Car that is popular
import numpy as np
import matplotlib.pyplot as plt

y = np.array([65505, 30221, 3778])
mylabels = ["Male", "Female", "Unknown"]
myexplode = [0.2, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, autopct='%.2f')
plt.legend(title = 'Preference 2:XE')
plt.show()

# %%
#10th Popular car
import numpy as np
import matplotlib.pyplot as plt

y = np.array([3867, 4960, 404])
mylabels = ["Male", "Female", "Unknown"]
myexplode = [0, 0.4, 0]

plt.pie(y, labels = mylabels, explode = myexplode, autopct='%.2f', startangle = 180)
plt.legend(title = 'Preference 10:Citigo', loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,10,1,1])


lang = ['Land-Rover', 'BMW', 'Jaguar', 'Audi', 'BMW','Porsche','Volvo', 'BMW','640i','Volvo']
students = [8.28,8,8,8,8,8,8,8,8,8]
ax.bar(lang,students)

plt.title('Top 10 Car Model Transmissions by Males')
plt.xlabel('Manufacturer Cars')
plt.ylabel('Transmission')
plt.show()

# %%
# 2.2 
PriceandPower = Mainfile.copy()
#PriceandPower = PriceandPower.drop(columns=['Model'])
PriceandPower = PriceandPower.drop(columns=['Transmission'])
PriceandPower = PriceandPower.drop(columns=['Engine CC'])
PriceandPower = PriceandPower.drop(columns=['Fuel'])
PriceandPower = PriceandPower.drop(columns=['Female'])
PriceandPower = PriceandPower.drop(columns=['Male'])
PriceandPower = PriceandPower.drop(columns=['Unknown'])
PriceandPower = PriceandPower.drop(columns=['Total'])
#PriceandPower.groupby(['Model']).head()

#Looking at Price
PriceandPower = PriceandPower.groupby('Manufacturer')[['Manufacturer','Model','Price','Power']].head(10)                                                                        
PriceandPower.sort_values(['Power'],ascending=False).head(10)
# Out:
#      Manufacturer        Model   Price  Power
# 399       Porsche      Carrera  646.60  450.0
# 1428      Bentley  Continental  285.25  428.2
# 1823      Bentley  Continental  285.25  428.2
# 2193      Bentley  Continental  285.25  428.2
# 230       Bentley  Continental  285.25  428.2
# 2572      Bentley  Continental  285.25  428.2
# 1038      Bentley  Continental  285.25  428.2
# 2938      Bentley  Continental  285.25  428.2
# 3287      Bentley  Continental  285.25  428.2
# 3638      Bentley  Continental  285.25  428.2

# %%
PriceandPower['Power'].plot(kind='hist',bins=20)
plt.title('Power Histogram')
plt.xlabel('Car Power Usage')
plt.show()

# %%
PriceandPower['Price'].plot(kind='hist',bins=20)
plt.title('Price Histogram')
plt.xlabel('Car Price')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,10,1,1])

manus = ['Vantage', 'Bentley', 'Ferrari', 'Maserati', 'Porsche','TVR','Daimler', 'Lexus','Jaguar','Audi']
carprices = [360.76,285.25,260.29,245.17,158.79,107.70,92.80,78.48,65.57,57.93]
ax.bar(manus,carprices)

plt.title('Top 10 Cars by Price')
plt.xlabel('Manufacturer Cars')
plt.ylabel('Price')
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,10,1,1])

ax.bar(manus,students)
manus = ['Bentley', 'Aston-Martin', 'Ferrari', 'Maserati', 'Porsche','TVR','Lexus', 'Jaguar','Daimler','Audi']
students = [428.20,410.00,360.00,338.00,293.53,274.00,224.78,167.25,166.00,149.71]

plt.title('Top 10 Cars by Power')
plt.xlabel('Manufacturer Cars')
plt.ylabel('Power')
plt.show()

# %%
#2.3
#Here I have decided to explore the relationship 
#between the number of Male Owners to Model, Transmission and Fuel
MaleData = Mainfile.copy()
#MaleData = MaleData.drop(columns=['Manufacturer'])
MaleData = MaleData.drop(columns=['Engine CC'])
MaleData = MaleData.drop(columns=['Price'])
MaleData = MaleData.drop(columns=['Female'])
MaleData = MaleData.drop(columns=['Unknown'])
MaleData = MaleData.drop(columns=['Total'])
MaleData = MaleData.drop(columns=['Power'])

#MaleData = MaleData.groupby('Transmission')[['Manufacturer','Model','Transmission','Fuel','Male']].head(10)

#To Sort data by male numbers
MaleData = MaleData[['Manufacturer','Model','Transmission','Fuel','Male']].head(10)

#Looking at Model
MaleData.sort_values(['Male'],ascending=False).head(10)
# Out:
#    Manufacturer   Model  Transmission    Fuel    Male
# 4           BMW    320i          6.44  petrol  408016
# 7          Ford  Mondeo          1.75  petrol  357452
# 9         Honda   Civic          4.50  petrol  242188
# 3       Renault    Clio          5.62  petrol  241287
# 5    Volkswagen    Polo          5.07  petrol  216333
# 11      Renault  Megane          5.41  petrol  209379
# 6       Peugeot     206          4.83  petrol  178698
# 8        Nissan   Micra          4.87  petrol  143218
# 12       Toyota   Yaris          3.52  petrol  137907
# 10         Ford     Ka+          5.00  petrol  102708

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,10,1,1])


lang = ['Land-Rover', 'BMW', 'Jaguar', 'Audi', 'BMW']
students = [8.28,8,8,8,7]
ax.bar(lang,students)

plt.title('Top 10 Car Model Transmissions by Males')
plt.xlabel('Manufacturer Cars')
plt.ylabel('Transmission')
plt.show()

# %%
#2.3
MaleData = Mainfile.copy()
#MaleData = MaleData.drop(columns=['Manufacturer'])
MaleData = MaleData.drop(columns=['Engine CC'])
MaleData = MaleData.drop(columns=['Price'])
MaleData = MaleData.drop(columns=['Female'])
MaleData = MaleData.drop(columns=['Unknown'])
MaleData = MaleData.drop(columns=['Total'])
MaleData = MaleData.drop(columns=['Power'])



#To Sort data by transmission
MaleData = MaleData.groupby('Model')[['Manufacturer','Model','Transmission','Fuel','Male']].head(10)

#Looking at Model
MaleData.sort_values(['Transmission'],ascending=False).head(10)
# Out:
#      Manufacturer  Model  Transmission    Fuel    Male
# 1886   Land-Rover  Range          8.28  diesel    2951
# 1243   Land-Rover  Range          8.28  diesel   76869
# 377    Land-Rover  Range          8.28  diesel    1532
# 846    Land-Rover  Range          8.28  diesel   83312
# 752    Land-Rover  Range          8.28  diesel    1847
# 1633   Land-Rover  Range          8.28  diesel   70504
# 1126   Land-Rover  Range          8.28  diesel    2123
# 1504   Land-Rover  Range          8.28  diesel    2540
# 34     Land-Rover  Range          8.28  diesel  107520
# 445    Land-Rover  Range          8.28  diesel   94411

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,10,1,1])


lang = ['Land-Rover', 'BMW', 'Jaguar', 'Audi', 'BMW','Porsche','Volvo', 'BMW','640i','Volvo']
students = [8.28,8,8,8,8,8,8,8,8,8]
ax.bar(lang,students)

plt.title('Top 10 Car Model Transmissions by Males')
plt.xlabel('Manufacturer Cars')
plt.ylabel('Transmission')
plt.show()
